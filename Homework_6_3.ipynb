# %%
import quandl
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = quandl.get(["WWDI/ARM_TM_VAL_MRCH_CD_WT","WWDI/ARM_TX_VAL_MRCH_CD_WT"], authtoken = 'Please enter you API key')

# %%
data
# Out:
#             WWDI/ARM_TM_VAL_MRCH_CD_WT - Value  \
# Date
# 1994-12-31                        3.940000e+08
# 1995-12-31                        6.740000e+08
# 1996-12-31                        8.560000e+08
# 1997-12-31                        8.920000e+08
# 1998-12-31                        9.020000e+08
# 1999-12-31                        8.000000e+08
# 2000-12-31                        8.820000e+08
# 2001-12-31                        8.740000e+08
# 2002-12-31                        9.872000e+08
# 2003-12-31                        1.279500e+09
# 2004-12-31                        1.350700e+09
# 2005-12-31                        1.801700e+09
# 2006-12-31                        2.191600e+09
# 2007-12-31                        3.267800e+09
# 2008-12-31                        4.426100e+09
# 2009-12-31                        3.321100e+09
# 2010-12-31                        3.782880e+09
# 2011-12-31                        4.145300e+09
# 2012-12-31                        4.261200e+09
# ...

# %%
data["WWDI/ARM_TM_VAL_MRCH_CD_WT - Value"].plot()
data["WWDI/ARM_TX_VAL_MRCH_CD_WT - Value"].plot()
plt.show()
