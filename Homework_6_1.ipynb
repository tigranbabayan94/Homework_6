# %%
import quandl
import matplotlib.pyplot as plt

# %%
data = quandl.get(["WWDI/ARM_NY_TTF_GNFS_KN","WWDI/LUX_NY_TTF_GNFS_KN"], authtoken = 'Please enter you API key')

# %%
plt.plot(data["WWDI/LUX_NY_TTF_GNFS_KN - Value"])
plt.plot(data["WWDI/ARM_NY_TTF_GNFS_KN - Value"])
plt.show()
